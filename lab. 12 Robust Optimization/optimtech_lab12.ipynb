# %% [markdown]
# # Lab. 12: Robust Optimization
#
# ## Introduction
#
# #### <u>In this lab, we will see some applications of robust optimization, namely a modified version of the Knapsack 0/1 problem, and the portfolio optimization problem.</u>
#
# Your job in this lab is to implement the missing functions, and study how different functions lead to different outcomes from both the point of view of the objective value and the probability of violating the constraints of the problem.
#
# The examples are taken from https://xiongpengnus.github.io/rsome/ro_rsome, using the RSOME library for robust optimization.

# %%
# @title Imports

# !pip install -q rsome
# !pip install -q gurobipy

from rsome import ro
from rsome import grb_solver as grb
import rsome as rso
import numpy as np
import numpy.random as rd
import matplotlib.pyplot as plt
from math import floor
import pprint

# %% [markdown]
# ## Exercises

# %% [markdown]
# ### Exercise 1/2: Modified Knapsack 0/1 Problem

# %% [markdown]
# In this exercise, we will solve the Knapsack problem (seen in the previous labs), slightly modified in order to have uncertainties about the volumes of the items.
#
# The uncertainty about the volumes is not the same for all the items. They are defined by  δ , defined as a fraction of the size of the volumes of the items.
#
# In this exercise, you are asked to implement the definition of the uncertainty set in order to have both an ellipsoidal uncertainty set and a finite uncertainty set.
#
# #### Task
# Implement different sizes for the ellipsoid and different interval for the finite set and compare the objective values and the probability of violating the constraints with the different setups.

# %%
# @title Helper Functions

items = [
    {'name': 'apple', 'value': 1, 'volume': 2},
    {'name': 'pear', 'value': 2, 'volume': 2},
    {'name': 'banana', 'value': 2, 'volume': 2},
    {'name': 'watermelon', 'value': 5, 'volume': 10},
    {'name': 'orange', 'value': 3, 'volume': 2},
    {'name': 'avocado', 'value': 3, 'volume': 2},
    {'name': 'blueberry', 'value': 3, 'volume': 1},
    {'name': 'coconut', 'value': 4, 'volume': 3},
    {'name': 'cherry', 'value': 2, 'volume': 1},
    {'name': 'apricot', 'value': 1, 'volume': 1},
]

N = len(items)
b = 10

c = np.array([i['value'] for i in items]).flatten()  # profit coefficients
w = np.array([i['volume'] for i in items]).flatten()  # weight coefficients

delta = 0.2*w  # maximum deviations

def robust(get_uncertainty_set, r):
    """
    The function robust implements the robust optimiztion model,
    given the budget of uncertainty r
    """

    model = ro.Model('robust')
    x = model.dvar(N, vtype='B')  # Boolean variable x (0: leave, 1: keep)
    z = model.rvar(N)             # Random variable

    # Uncertainty set
    z_set = get_uncertainty_set(z, r)
    model.max(c @ x)              # Maximize the value of the knapsack (i.e., the dot product between the values and x)

    # Add constraint: the maximum (uncertain) volume is smaller than the budget
    # in ellipsoidal uncertainty set, 'M' is 'delta' and 'u' is 'z'
    # in finite uncertainty set, p1 = w + z1*delta => z1 = (p1 - w)/delta
    model.st(((w + z*delta) @ x <= b).forall(z_set))
    #consider the optimization with constraint "Ax <= b", here A = w + z*delta

    # Solve
    model.solve(grb, display=False)

    return model.get(), x.get()    # Return the optimal objective and solution


def sim(x_sol, zs):
    """
    The function sim is for calculating the probability of violation
    via simulations.
        x_sol: solution of the Knapsack problem
        zs: random sample of the random variable z
    """

    ws = w + zs*delta   # random samples of uncertain weights

    return (ws @ x_sol > b).mean()


def ellipsoidal_uncertainty_set(z, r):
    """
    Define an uncertainty set. See the following sources:
    - Ellipsoidal: https://xiongpengnus.github.io/rsome/ro_rsome#section2.2
    - Finite Uncertainty Set
    """
    z_set = (rso.norm(z, 2) <= r)
    return z_set

def finite_uncertainty_set(z, r):
    z_set = (
        (z <= r[0], z >= r[0]) or
        (z <= r[1], z >= r[1]) or
        (z <= r[2], z >= r[2])
    )
    return z_set

def finite_uncertainty_set_big(z, r):
    z_set = (
        (z <= r[0], z >= r[0]) or
        (z <= r[1], z >= r[1]) or
        (z <= r[2], z >= r[2]) or
        (z <= r[3], z >= r[3]) or
        (z <= r[4], z >= r[4]) or
        (z <= r[5], z >= r[5])
    )
    return z_set

def finite_uncertainty_set_hardcoded(z, r):
    z_set = (
        (z <= 0, z >= 0) or
        (z <= 1, z >= 1) or
        (z <= 2, z >= 2) or
        (z <= 3, z >= 3) or
        (z <= 4, z >= 4) or
        (z <= 5, z >= 5)
    )
    return z_set

# %%
num_samples = 20000
zs = np.random.uniform(-1, 1, (num_samples, N))  # Generate random samples for z

objective_value, solution = robust(ellipsoidal_uncertainty_set, 1)
prob_violation = sim(solution, zs)

print(f'Content of the knapsack:')
for i, value in enumerate(solution):
    if value:
        print(f'\t{items[i]["name"]}')
print(f'Total value: {objective_value}. Probability of violation: {prob_violation}')
# Out:
# Content of the knapsack:
# 	orange
# 	avocado
# 	blueberry
# 	coconut
# 	cherry
# Total value: 15.0. Probability of violation: 0.0199

# %%
# TODO
# Implement different sizes for the ellipsoid and different interval for the finite set and compare the objective values and the probability of violating the constraints with the different setups.
# Analyze different setups
ellipsoidal_radii = [0.5, 1, 2, 3]
finite_intervals = [
    [-0.1, 0, 0.1],
    [-0.5, 0, 0.5],
    [-1, 0, 1],
    [-2, -1, 0, 1, 2],
]

results = []

# Ellipsoidal uncertainty set with different radii
for r in ellipsoidal_radii:
    objective_value, solution = robust(ellipsoidal_uncertainty_set, r)
    prob_violation = sim(solution, zs)
    results.append({
        'type': 'Ellipsoidal',
        'r': r,
        'objective_value': objective_value,
        'prob_violation': prob_violation,
    })

# Finite uncertainty set with different intervals
for r in finite_intervals:
    objective_value, solution = robust(finite_uncertainty_set, r)
    prob_violation = sim(solution, zs)
    results.append({
        'type': 'Finite',
        'r': r,
        'objective_value': objective_value,
        'prob_violation': prob_violation,
    })

# Print the results
for result in results:
    print(f"Uncertainty Set Type: {result['type']}")
    print(f"Uncertainty Parameters (r): {result['r']}")
    print(f"Objective Value: {result['objective_value']}")
    print(f"Probability of Violation: {result['prob_violation']}\n")
# Out:
# Uncertainty Set Type: Ellipsoidal
# Uncertainty Parameters (r): 0.5
# Objective Value: 15.0
# Probability of Violation: 0.0199
#
# Uncertainty Set Type: Ellipsoidal
# Uncertainty Parameters (r): 1
# Objective Value: 15.0
# Probability of Violation: 0.0199
#
# Uncertainty Set Type: Ellipsoidal
# Uncertainty Parameters (r): 2
# Objective Value: 13.0
# Probability of Violation: 0.0
#
# Uncertainty Set Type: Ellipsoidal
# Uncertainty Parameters (r): 3
# Objective Value: 12.0
# Probability of Violation: 0.0
#
# Uncertainty Set Type: Finite
# Uncertainty Parameters (r): [-0.1, 0, 0.1]
# Objective Value: 16.0
# Probability of Violation: 0.50415
#
# Uncertainty Set Type: Finite
# Uncertainty Parameters (r): [-0.5, 0, 0.5]
# Objective Value: 17.0
# Probability of Violation: 0.9636
#
# Uncertainty Set Type: Finite
# Uncertainty Parameters (r): [-1, 0, 1]
# Objective Value: 18.0
# Probability of Violation: 1.0
#
# Uncertainty Set Type: Finite
# Uncertainty Parameters (r): [-2, -1, 0, 1, 2]
# Objective Value: 21.0
# Probability of Violation: 1.0

# %%
# Plot the results
ellipsoidal_results = [res for res in results if res['type'] == 'Ellipsoidal']
finite_results = [res for res in results if res['type'] == 'Finite']

plt.figure(figsize=(12, 6))

# Plot for Ellipsoidal Uncertainty Set
plt.subplot(1, 2, 1)
plt.plot([res['r'] for res in ellipsoidal_results], [res['objective_value'] for res in ellipsoidal_results], marker='o', label='Objective Value')
plt.plot([res['r'] for res in ellipsoidal_results], [res['prob_violation'] for res in ellipsoidal_results], marker='x', label='Probability of Violation')
plt.xlabel('Ellipsoidal Radius')
plt.ylabel('Value')
plt.title('Ellipsoidal Uncertainty Set')
plt.legend()

# Plot for Finite Uncertainty Set
plt.subplot(1, 2, 2)
plt.plot([len(res['r']) for res in finite_results], [res['objective_value'] for res in finite_results], marker='o', label='Objective Value')
plt.plot([len(res['r']) for res in finite_results], [res['prob_violation'] for res in finite_results], marker='x', label='Probability of Violation')
plt.xlabel('Number of Intervals')
plt.ylabel('Value')
plt.title('Finite Uncertainty Set')
plt.legend()

# %%
# Plot the results
ellipsoidal_results = [res for res in results if res['type'] == 'Ellipsoidal']
finite_results = [res for res in results if res['type'] == 'Finite']

plt.figure(figsize=(12, 6))

# Plot for Ellipsoidal Uncertainty Set
plt.subplot(1, 2, 1)
ax1 = plt.gca()
ax2 = ax1.twinx()
ax1.plot([res['r'] for res in ellipsoidal_results], [res['objective_value'] for res in ellipsoidal_results], marker='o', color='b', label='Objective Value')
ax2.plot([res['r'] for res in ellipsoidal_results], [res['prob_violation'] for res in ellipsoidal_results], marker='x', color='r', label='Probability of Violation')
ax1.set_xlabel('Ellipsoidal Radius')
ax1.set_ylabel('Objective Value', color='b')
ax2.set_ylabel('Probability of Violation', color='r')
ax1.set_title('Ellipsoidal Uncertainty Set')
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# Plot for Finite Uncertainty Set
plt.subplot(1, 2, 2)
ax1 = plt.gca()
ax2 = ax1.twinx()
ax1.plot([len(res['r']) for res in finite_results], [res['objective_value'] for res in finite_results], marker='o', color='b', label='Objective Value')
ax2.plot([len(res['r']) for res in finite_results], [res['prob_violation'] for res in finite_results], marker='x', color='r', label='Probability of Violation')
ax1.set_xlabel('Number of Intervals')
ax1.set_ylabel('Objective Value', color='b')
ax2.set_ylabel('Probability of Violation', color='r')
ax1.set_title('Finite Uncertainty Set')
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %%
# Plot for Ellipsoidal Uncertainty Set
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot([res['r'] for res in ellipsoidal_results], [res['objective_value'] for res in ellipsoidal_results], marker='o', label='Objective Value')
plt.plot([res['r'] for res in ellipsoidal_results], [res['prob_violation'] for res in ellipsoidal_results], marker='x', label='Probability of Violation')
plt.xlabel('Ellipsoidal Radius')
plt.ylabel('Value')
plt.title('Ellipsoidal Uncertainty Set')
plt.legend()



# Scaled
plt.subplot(1, 2, 2)
ax1 = plt.gca()
ax2 = ax1.twinx()
ax1.plot([res['r'] for res in ellipsoidal_results], [res['objective_value'] for res in ellipsoidal_results], marker='o', color='b', label='Objective Value')
ax2.plot([res['r'] for res in ellipsoidal_results], [res['prob_violation'] for res in ellipsoidal_results], marker='x', color='r', label='Probability of Violation')
ax1.set_xlabel('Ellipsoidal Radius')
ax1.set_ylabel('Objective Value', color='b')
ax2.set_ylabel('Probability of Violation', color='r')
ax1.set_title('(Scaled) Ellipsoidal Uncertainty Set')
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %%
# Plot for Finite Uncertainty Set
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot([len(res['r']) for res in finite_results], [res['objective_value'] for res in finite_results], marker='o', label='Objective Value')
plt.plot([len(res['r']) for res in finite_results], [res['prob_violation'] for res in finite_results], marker='x', label='Probability of Violation')
plt.xlabel('Number of Intervals')
plt.ylabel('Value')
plt.title('Finite Uncertainty Set')
plt.title('Finite Uncertainty Set')
plt.legend()

# Plot for Scaled Finite Uncertainty Set
plt.subplot(1, 2, 2)
ax1 = plt.gca()
ax2 = ax1.twinx()
ax1.plot([len(res['r']) for res in finite_results], [res['objective_value'] for res in finite_results], marker='o', color='b', label='Objective Value')
ax2.plot([len(res['r']) for res in finite_results], [res['prob_violation'] for res in finite_results], marker='x', color='r', label='Probability of Violation')
ax1.set_xlabel('Number of Intervals')
ax1.set_ylabel('Objective Value', color='b')
ax2.set_ylabel('Probability of Violation', color='r')
ax1.set_title('(Scaled) Finite Uncertainty Set')
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Exercise 2/2: Robust Portfolio Optimization

# %% [markdown]
# In this problem, we want to build a portfolio (e.g., of stocks), by using robust approaches.
#
# To be more specific, in this problem we have a set of fictionary stocks, each of which has different means and deviations for the returns.
#
# #### TASK
# Your job here is to implement a box uncertainty set to robustly optimize the portfolio. Try different values for the box in order to study how the uncertainty affects the objective value of and the number of different stocks chosen.

# %%
# @title Helper Functions

n = 10
stocks = {
    f'Company {chr(65+i)}': {'Mean': np.around(np.random.uniform(0.9, 1.1), 2), 'Deviation': np.around(np.random.uniform(0.1, 0.3), 2)}
    for i in range(n)
}

stocks = {
    'Company A': {'Deviation': 0.17, 'Mean': 0.97},
    'Company B': {'Deviation': 0.22, 'Mean': 0.92},
    'Company C': {'Deviation': 0.28, 'Mean': 0.95},
    'Company D': {'Deviation': 0.22, 'Mean': 1.04},
    'Company E': {'Deviation': 0.23, 'Mean': 0.97},
    'Company F': {'Deviation': 0.24, 'Mean': 1.08},
    'Company G': {'Deviation': 0.27, 'Mean': 1.05},
    'Company H': {'Deviation': 0.12, 'Mean': 1.01},
    'Company I': {'Deviation': 0.24, 'Mean': 1.03},
    'Company J': {'Deviation': 0.29, 'Mean': 0.95}
}

def portfolio_optimization(get_uncertainty_set, l, u):
    p = np.array([stocks[s]['Mean'] for s in stocks])  # mean returns
    delta = np.array([stocks[s]['Deviation'] for s in stocks])  # deviations of returns
    Gamma = 5                               # budget of uncertainty

    model = ro.Model()
    x = model.dvar(n)                       # fractions of investment
    z = model.rvar(n)                       # random variables

    z_set = get_uncertainty_set(z, l, u)

    model.maxmin(
        (p + delta*z) @ x,                  # the max-min objective
        z_set
    )

    model.st(sum(x) == 1)                   # summation of x is one
    model.st(x >= 0)                        # x is non-negative

    model.solve(grb)                        # solve the model by Gurobi
    return model.get(), x.get()


def get_uncertainty_set_po(z, l, u):
    """
    Return a box uncertainty set
    (see https://xiongpengnus.github.io/rsome/example_ro_inv).

    Try different values for the size of the box.
    """
    z_set = (
        z <= u,
        z >= l
    )
    return z_set

def get_uncertainty_set_po_norm(z, l, u):
    """
    Return a box uncertainty set
    (see https://xiongpengnus.github.io/rsome/example_ro_inv).

    Try different values for the size of the box.
    """
    z_set = (
        rso.norm(z, 1) <= u
    )
    return z_set

# %%
obj_val, x_sol = portfolio_optimization(get_uncertainty_set_po_norm, -1, 1)

plt.bar(
    [s.split(' ')[1] for s in stocks],  # Stock names
    x_sol,                              # Fraction of the portfolio
)
plt.xlabel('Stocks')
plt.ylabel('Fraction of investment')
plt.show()
print('Objective value: {0:0.4f}'.format(obj_val))
# Out:
# Being solved by Gurobi...
# Solution status: 2
# Running time: 0.0000s
# Objective value: 0.9963

# %%
# Define different values for l and u
uncertainty_bounds = [(0.1, 0.1),(-0.5, 0.5), (-1, 1), (-3, 2)]

# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(15, 10))

# Iterate over different values for l and u
for (l, u), ax in zip(uncertainty_bounds, axs.flatten()):
    obj_val, x_sol = portfolio_optimization(get_uncertainty_set_po_norm, l, u)
    
    ax.bar(
        [s.split(' ')[1] for s in stocks],  # Stock names
        x_sol,  # Fraction of the portfolio
    )
    ax.set_xlabel('Stocks')
    ax.set_ylabel('Fraction of investment')
    ax.set_title(f'Uncertainty set: l={l}, u={u}')
    
    # Annotate with objective value and number of different stocks chosen
    ax.text(0.95, 0.95, f'Objective value: {obj_val:0.4f}', transform=ax.transAxes, 
            verticalalignment='top', horizontalalignment='right', bbox=dict(facecolor='white', alpha=0.5))
    ax.text(0.95, 0.85, f'Stocks chosen: {np.count_nonzero(x_sol)}', transform=ax.transAxes, 
            verticalalignment='top', horizontalalignment='right', bbox=dict(facecolor='white', alpha=0.5))

    print(f'Objective value (l={l}, u={u}): {obj_val:0.4f}')
    print(f'Number of different stocks chosen (l={l}, u={u}): {np.count_nonzero(x_sol)}\n')

# Adjust layout
plt.tight_layout()
plt.show()
# Out:
# Being solved by Gurobi...
# Solution status: 2
# Running time: 0.0010s
# Objective value (l=0.1, u=0.1): 1.0560
# Number of different stocks chosen (l=0.1, u=0.1): 1
#
# Being solved by Gurobi...
# Solution status: 2
# Running time: 0.0000s
# Objective value (l=-0.5, u=0.5): 1.0196
# Number of different stocks chosen (l=-0.5, u=0.5): 4
#
# Being solved by Gurobi...
# Solution status: 2
# Running time: 0.0000s
# Objective value (l=-1, u=1): 0.9963
# Number of different stocks chosen (l=-1, u=1): 5
#
# Being solved by Gurobi...
# Solution status: 2
# Running time: 0.0000s
# Objective value (l=-3, u=2): 0.9602
# Number of different stocks chosen (l=-3, u=2): 7

# %%
fig, (ax2, ax3) = plt.subplots(2, 1, figsize=(15, 15))

# Plot portfolio allocations

labels = [s.split(' ')[1] for s in stocks]


# Plot objective values
ax2.plot([f'l={l}, u={u}' for (l, u) in uncertainty_bounds], objective_values, marker='o')
ax2.set_xlabel('Uncertainty Sets')
ax2.set_ylabel('Objective Value')
ax2.set_title('Objective Value for Different Uncertainty Sets')

# Plot number of different stocks chosen
ax3.plot([f'l={l}, u={u}' for (l, u) in uncertainty_bounds], stocks_chosen_counts, marker='o', color='r')
ax3.set_xlabel('Uncertainty Sets')
ax3.set_ylabel('Number of Different Stocks Chosen')
ax3.set_title('Number of Different Stocks Chosen for Different Uncertainty Sets')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# TODO
